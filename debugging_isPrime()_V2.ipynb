# %% [markdown]
# <a href="https://colab.research.google.com/github/MiaEastman/Introduction-to-Business-Programming/blob/main/debugging_isPrime()_V2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Debug isPrime()
# What is your preferred method? Do you like using print() or prefer *pdb*?   Since mistakes in programs will happen, the important part is that you have a debugging strategy, not which tool you use.
#
# Here is a function that needs debugging. Using either print() or *pdb*, debug the following function.

# %%
#Original

def isPrime(candidate):
    if candidate <= 1:
        return False

    lower = candidate - 1
    while lower > 1:
        if candidate / lower == candidate // lower:
            return False
        lower -= 1

    return True

# %%
isPrime(7)
# Out:
# True

# %%
isPrime(-2)
# Out:
# False

# %%
isPrime(5.5)
# Out:
# True

# %% [markdown]
# isPrime(5.5) should be false because prime numbers cannot be decimals (float).The // is used in the == expression removes this whole number requirement because it's saying as long as the starting whole number is the same it doesn't what or if there are decimals following. That statement is incorrect for prime numbers.

# %% [markdown]
# isprime() is a built-in function under the SymPy module and can be utilized for checking of possible prime numbers. It is a direct function and returns True if the number to be checked is prime and False if the number is not prime.

# %%
#Attempt 1

def isPrime(candidate):
    if candidate <= 1:
        return False

    lower = candidate - 1
    while lower > 1:
        if candidate / lower == candidate / lower:
            return False
        lower -= 1

    return True

isPrime(5.5)
# Out:
# False

# %%
#Attempt 2

def isPrime(candidate):
    print("candidate: ", candidate)
    #candidate = 0
    if candidate <= 1:
      #print(candidate)
      #print(type(candidate))
      return False

    lower = candidate - 1
    while lower > 1:
        print("lower:",lower)
        if candidate / lower == candidate / lower:
            print("lower inside if:", lower)
            return False
        #print(lower)
        lower -= 1
        #print(lower)

    return True

candidate = int(input('Please enter a candidate  : '))
isPrime(candidate)
# Out:
# Please enter a candidate  : 7
# candidate:  7
# lower: 6
# lower inside if: 6
# False

# %%
#Attempt 2

def isPrime(candidate):
    if candidate <= 1:
        return False

    lower = candidate - 1
    while lower > 1:
        if candidate / lower == candidate // lower:
            return False
        lower -= 1

    return True
isPrime(input('Please enetr a candidate  : '))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# --> 625         parts = [self.recv(flags, copy=copy, track=track)]
#     626         # have first part already, only loop while more to receive
#
# ...

# %%
#Attempt 3

def isPrime(candidate):
    print("candidate: ", candidate)
    #candidate = 0
    if candidate <= 1:
      #print(candidate)
      #print(type(candidate))
      return False

    lower = candidate - 1
    while lower > 1:
       print("lower: ", lower)
    if candidate / lower == candidate // lower:
            #print(lower)
            return False
        #print(lower)
    lower -= 1
        #print(lower)
    return True

candidate = int(input('Please enter a candidate  : '))
isPrime(candidate)
# Out:
# Streaming output truncated to the last 5000 lines.
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# lower:  6
# ...

# %% [markdown]
# the -= represents a decrement which is a operator used to reduce the value of a variable by 1
